# %%
import pandas as pd
import os
import glob

# Ruta a la carpeta
path = 'LinkedIn/Data'  

# Construye la ruta completa y busca todos los archivos CSV en la carpeta
all_files = glob.glob(os.path.join(path, "*.csv"))

# Lista para almacenar cada DataFrame leído de cada archivo CSV
dfs = []

# Itera sobre los archivos encontrados y los añade a la lista de DataFrames
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    dfs.append(df)

# Combina todos los DataFrames de la lista en uno solo
combined_df = pd.concat(dfs, axis=0, ignore_index=True)

# Muestra el DataFrame combinado
print(combined_df)
#combined_df.to_excel("_output/desa_linked_df.xlsx")
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Trainee Tienda Falabella Copiapó / Media Jorna...
# 1              0  Trainee Tienda Falabella La Dehesa /Sabados y ...
# 2              0  Trainee Seguridad Falabella Puente/ Full Time ...
# 3              0  Trainee de Seguridad/Atención en Probadores Fa...
# 4              0               Practica de Rentabilidad de Precios
# ...          ...                                                ...
# 5963           0  Apoyo Cyber Day Retail, Full Time 44 hrs / Fal...
# 5964           0                      Senior Mobile Engineer (iOS)
# 5965           0  Developer Backend Senior - Java y Microservicios
# 5966           0                                 Desarrollador RPG
# 5967           0      Cloud Security Engineer (Temporary Position)
#
#                                                    Link        Company  \
# 0     https://www.linkedin.com/jobs/view/3981413912/...      Falabella
# 1     https://www.linkedin.com/jobs/view/3925967244/...      Falabella
# 2     https://www.linkedin.com/jobs/view/3928440766/...      Falabella
# 3     https://www.linkedin.com/jobs/view/3976909106/...      Falabella
# 4     https://www.linkedin.com/jobs/view/3984757425/...        Sodimac
# ...                                                 ...            ...
# 5963  https://www.linkedin.com/jobs/view/4002173965/...      Falabella
# 5964  https://www.linkedin.com/jobs/view/3988782634/...  Apply Digital
# 5965  https://www.linkedin.com/jobs/view/3967803656/...             EY
# 5966  https://www.linkedin.com/jobs/view/3997587376/...         SOAINT
# 5967  https://www.linkedin.com/jobs/view/3997644543/...       Applaudo
#
#                                                Location  \
# 0                     Copiapó, Región de Atacama, Chile
# 1     Lo Barnechea, Región Metropolitana de Santiago...
# 2     Gran Santiago, Región Metropolitana de Santiag...
# 3     Lo Barnechea, Región Metropolitana de Santiago...
# 4        Renca, Región Metropolitana de Santiago, Chile
# ...                                                 ...
# 5963                Valdivia, Región de Los Ríos, Chile
# 5964  Gran Santiago, Región Metropolitana de Santiag...
# 5965                     Área metropolitana de Santiago
# 5966                                              Chile
# 5967                                              Chile
#
#                                 Time_on                 Applies  \
# 0                        hace 2 semanas          12 solicitudes
# 1     Publicado de nuevo hace 2 semanas           6 solicitudes
# 2        Publicado de nuevo hace 6 días          11 solicitudes
# 3        Publicado de nuevo hace 3 días          11 solicitudes
# 4                        hace 2 semanas          11 solicitudes
# ...                                 ...                     ...
# 5963                      hace 1 semana          18 solicitudes
# 5964   Publicado de nuevo hace 1 semana          19 solicitudes
# 5965   Publicado de nuevo hace 1 semana  Más de 100 solicitudes
# 5966                     hace 2 semanas          42 solicitudes
# 5967                     hace 2 semanas          16 solicitudes
#
#            Working_day  Experience  Company_size  Company_area  \
# 0            Prácticas         NaN           NaN           NaN
# 1            Prácticas         NaN           NaN           NaN
# 2            Prácticas         NaN           NaN           NaN
# 3            Prácticas         NaN           NaN           NaN
# 4      Sin experiencia         NaN           NaN           NaN
# ...                ...         ...           ...           ...
# 5963         Prácticas         NaN           NaN           NaN
# 5964  Jornada completa  Intermedio           NaN           NaN
# 5965  Jornada completa  Intermedio           NaN           NaN
# 5966  Jornada completa  Intermedio           NaN           NaN
# 5967  Jornada completa  Intermedio           NaN           NaN
#
#                                                    Apts  \
# 0     ['Capacidad de análisis', 'Comunicación', 'Ing...
# 1     ['Comunicación', 'Resolución de problemas', 'T...
# 2     ['Boutique', 'Closeout', 'Control de acceso', ...
# 3     ['Circuito cerrado de televisión', 'Closeout',...
# 4     ['Actitud positiva', 'Análisis de datos', 'Cap...
# ...                                                 ...
# 5963  ['Compras', 'Comunicación', 'Entrega al client...
# 5964  ['Ciencias de la computación', 'Coding Standar...
# 5965  ['Desarrollo de software', 'Desarrollo web bac...
# 5966  ['Automatización de la compilación', 'Automati...
# 5967  ['Ciberseguridad', 'Google Cloud', 'Privacidad...
#
#                                             Description    Keyword
# 0     Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 1     Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 2     Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 3     Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 4     Descripción Empresa\n\nSomosFalabella\n\nSomos...  Actuación
# ...                                                 ...        ...
# 5963  Descripción Empresa\n\nSomos Falabella Retail\...   Software
# 5964  About Apply Digital\n\nApply Digital is a glob...   Software
# 5965  En EY, tendrás la oportunidad de desarrollar u...   Software
# 5966  En SOAINT tenemos más de 15 años dedicados a t...   Software
# 5967  Job Description\nAbout you\nYou are someone wh...   Software
#
# [5968 rows x 14 columns]

# %%
combined_df.head(5)
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Trainee Tienda Falabella Copiapó / Media Jorna...
# 1           0  Trainee Tienda Falabella La Dehesa /Sabados y ...
# 2           0  Trainee Seguridad Falabella Puente/ Full Time ...
# 3           0  Trainee de Seguridad/Atención en Probadores Fa...
# 4           0               Practica de Rentabilidad de Precios
#
#                                                 Link    Company  \
# 0  https://www.linkedin.com/jobs/view/3981413912/...  Falabella
# 1  https://www.linkedin.com/jobs/view/3925967244/...  Falabella
# 2  https://www.linkedin.com/jobs/view/3928440766/...  Falabella
# 3  https://www.linkedin.com/jobs/view/3976909106/...  Falabella
# 4  https://www.linkedin.com/jobs/view/3984757425/...    Sodimac
#
#                                             Location  \
# 0                  Copiapó, Región de Atacama, Chile
# 1  Lo Barnechea, Región Metropolitana de Santiago...
# 2  Gran Santiago, Región Metropolitana de Santiag...
# 3  Lo Barnechea, Región Metropolitana de Santiago...
# 4     Renca, Región Metropolitana de Santiago, Chile
#
#                              Time_on         Applies      Working_day  \
# 0                     hace 2 semanas  12 solicitudes        Prácticas
# 1  Publicado de nuevo hace 2 semanas   6 solicitudes        Prácticas
# 2     Publicado de nuevo hace 6 días  11 solicitudes        Prácticas
# 3     Publicado de nuevo hace 3 días  11 solicitudes        Prácticas
# 4                     hace 2 semanas  11 solicitudes  Sin experiencia
#
#   Experience  Company_size  Company_area  \
# 0        NaN           NaN           NaN
# 1        NaN           NaN           NaN
# 2        NaN           NaN           NaN
# 3        NaN           NaN           NaN
# 4        NaN           NaN           NaN
#
#                                                 Apts  \
# 0  ['Capacidad de análisis', 'Comunicación', 'Ing...
# 1  ['Comunicación', 'Resolución de problemas', 'T...
# 2  ['Boutique', 'Closeout', 'Control de acceso', ...
# 3  ['Circuito cerrado de televisión', 'Closeout',...
# 4  ['Actitud positiva', 'Análisis de datos', 'Cap...
#
#                                          Description    Keyword
# 0  Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 1  Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 2  Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 3  Descripción Empresa\n\nSomos más de 100 mil pe...  Actuación
# 4  Descripción Empresa\n\nSomosFalabella\n\nSomos...  Actuación

# %%
combined_df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Link', 'Company', 'Location', 'Time_on',
#        'Applies', 'Working_day', 'Experience', 'Company_size', 'Company_area',
#        'Apts', 'Description', 'Keyword'],
#       dtype='object')

# %%
master_df = combined_df.drop('Unnamed: 0', axis=1)
master_df.columns
# Out:
# Index(['Title', 'Link', 'Company', 'Location', 'Time_on', 'Applies',
#        'Working_day', 'Experience', 'Company_size', 'Company_area', 'Apts',
#        'Description', 'Keyword'],
#       dtype='object')

# %%
filtered_df = master_df.drop_duplicates(subset=['Title', 'Description', 'Company'], keep='first', inplace=False)
print(master_df.shape)
filtered_df = filtered_df[filtered_df['Keyword'] == 'Data Scientist']
print(filtered_df.shape)

#filtered_df.to_excel("_output/desa_linked_df.xlsx")
# Out:
# (5968, 13)
# (500, 13)

# %%
import ast
from collections import Counter

# Filtrar las filas que tienen valores no nulos en la columna 'Apts'
filtered_df = filtered_df.dropna(subset=['Apts'])

# Convertir las cadenas de caracteres a listas
filtered_df['Apts'] = filtered_df['Apts'].apply(ast.literal_eval)

# Crear una lista plana de todos los elementos en la columna 'Apts'
apts_list = [apt for sublist in filtered_df['Apts'] for apt in sublist]

# Contar la frecuencia de cada elemento
apt_counts = Counter(apts_list)

# Obtener los elementos más comunes y sus recuentos
top_apts = apt_counts.most_common()

print(top_apts)
# Out:
# [('Todos los filtros', 477), ('Comunicación', 173), ('Inglés', 114), ('Trabajo en equipo', 101), ('Ventas', 91), ('Liderazgo de equipos', 90), ('Resolución de problemas', 65), ('Boutique', 57), ('Capacidad de análisis', 55), ('Wine Cellars', 47), ('Negociación', 42), ('Dirección de equipos', 36), ('SQL', 33), ('Educación secundaria', 33), ('Gestión de ventas', 31), ('Gestión de caja', 29), ('Investigación', 28), ('Promotores', 27), ('Python', 26), ('Turnover', 26), ('Marketing', 25), ('Microsoft Excel', 24), ('Ayudar a los clientes', 24), ('Bases de datos', 23), ('Desarrollo de software', 23), ('Proceso de ventas', 22), ('Estándares de servicio', 20), ('Gestión de relaciones con clientes (CRM)', 20), ('Atención al cliente', 20), ('Hablar en público', 19), ('Compras', 19), ('Entrega de productos', 18), ('JavaScript', 17), ('Entrega al cliente', 17), ('Aptitudes de organización', 16), ('Ventas minoristas', 16), ('Atención al detalle', 15), ('Control de acceso', 14), ('Hojas de estilos en cascada (CSS)', 14), ('Actitud positiva', 14), ('Google Cloud', 14), ('Seguridad', 13), ('Promoción inmobiliaria', 13), ('Java', 12), ('Ciencias de la computación', 12), ('Integración de equipos', 12), ('Analítica', 11), ('Ciencia de datos', 11), ('Resolución de incidencias', 11), ('Cartera de clientes', 11), ('Recursos humanos (RR. HH.)', 11), ('Documentación', 11), ('Desarrollo web back end', 10), ('Habilidades sociales', 10), ('Soporte técnico', 10), ('DevOps', 10), ('Análisis de datos', 10), ('Instalation', 9), ('Analítica de datos', 9), ('Finanzas', 9), ('Occupational Risk Prevention', 9), ('Panel de control', 9), ('Closeout', 8), ('Outings', 8), ('Procedural', 8), ('Visualización de datos', 8), ('Seguridad privada', 8), ('C#', 8), ('Venta de productos', 8), ('Control de calidad', 8), ('Comunicación escrita', 8), ('HTML', 8), ('Buena práctica clínica', 8), ('Estrategia de marketing', 8), ('Carretillas elevadoras', 8), ('Gestión de seguridad', 7), ('Operaciones de seguridad', 7), ('Programación', 7), ('Seguridad del personal', 7), ('Administración de bases de datos', 7), ('Retención de clientes', 7), ('Extraer, transformar y cargar (ETL)', 7), ('Atención telefónica', 7), ('Apache Kafka', 7), ('Seguimiento', 7), ('Informes', 7), ('Administración de la caja registradora', 7), ('Protección de ejecutivos', 6), ('Mobiliario', 6), ('Kotlin', 6), ('Metodologías ágiles', 6), ('Ingeniería civil', 6), ('Objetivos financieros', 6), ('Extintores', 6), ('Remodelación', 6), ('Dotación de personal', 6), ('Automatización', 6), ('Coaching', 6), ('Docencia', 6), ('Introducción de datos', 6), ('Productos SAP', 6), ('Investigación de mercado', 6), ('Comercio minorista', 6), ('Evaluación de riesgos', 6), ('Recepción', 6), ('Estrategia empresarial', 6), ('Trabajos en altura', 6), ('Mantenimiento preventivo', 6), ('Mantenimiento y reparaciones', 6), ('Gestión comercial', 6), ('Lenguajes de programación', 5), ('Angular', 5), ('Programación en C', 5), ('Cumplimiento de estándares', 5), ('Marketing orientado al público objetivo', 5), ('Remodelaciones', 5), ('Desarrollo de oportunidades de negocio', 5), ('Para empresas (B2B)', 5), ('Minería', 5), ('Automatización de pruebas', 5), ('Tableau', 5), ('Aprendizaje automático', 5), ('Maquinaria de construcción', 5), ('Presentaciones', 5), ('Prevención', 5), ('Android', 5), ('SAP FI', 5), ('Contenedorización', 5), ('Fragancia', 5), ('Salesforce.com', 5), ('Campañas', 5), ('Diseño gráfico', 5), ('Gestión de cuentas', 5), ('Facilidad de adaptación', 5), ('Gestión financiera', 5), ('Indicadores clave de desempeño', 5), ('Análisis de riesgos', 5), ('Aptitudes para la supervisión', 5), ('Scala', 4), ('Node.js', 4), ('Query Languages', 4), ('Estrategias de mitigación', 4), ('Políticas y procedimientos', 4), ('Formación', 4), ('Comercial', 4), ('Gestión de existencias', 4), ('Satisfacción del cliente', 4), ('Arquitectura de datos', 4), ('Modelado de datos', 4), ('NoSQL', 4), ('Integración continua y entrega continua (CI/CD)', 4), ( ...

# %%
result = pd.DataFrame(top_apts, columns=['Aptitud', 'Frecuencia'])

# Mostrar el DataFrame
result.head(40)
# Out:
#                                      Aptitud  Frecuencia
# 0                          Todos los filtros         477
# 1                               Comunicación         173
# 2                                     Inglés         114
# 3                          Trabajo en equipo         101
# 4                                     Ventas          91
# 5                       Liderazgo de equipos          90
# 6                    Resolución de problemas          65
# 7                                   Boutique          57
# 8                      Capacidad de análisis          55
# 9                               Wine Cellars          47
# 10                               Negociación          42
# 11                      Dirección de equipos          36
# 12                                       SQL          33
# 13                      Educación secundaria          33
# 14                         Gestión de ventas          31
# 15                           Gestión de caja          29
# 16                             Investigación          28
# 17                                Promotores          27
# 18                                    Python          26
# 19                                  Turnover          26
# 20                                 Marketing          25
# 21                           Microsoft Excel          24
# 22                     Ayudar a los clientes          24
# 23                            Bases de datos          23
# 24                    Desarrollo de software          23
# 25                         Proceso de ventas          22
# 26                    Estándares de servicio          20
# 27  Gestión de relaciones con clientes (CRM)          20
# 28                       Atención al cliente          20
# 29                         Hablar en público          19
# 30                                   Compras          19
# 31                      Entrega de productos          18
# 32                                JavaScript          17
# 33                        Entrega al cliente          17
# 34                 Aptitudes de organización          16
# 35                         Ventas minoristas          16
# 36                       Atención al detalle          15
# 37                         Control de acceso          14
# 38         Hojas de estilos en cascada (CSS)          14
# 39                          Actitud positiva          14
